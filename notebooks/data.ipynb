# %% [markdown]
# # Citibike Data Retrieval

# %%
# Core data handling
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Date/time handling
from datetime import datetime

import gdown

# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %%
# Create data folder if it doesn't exist
os.makedirs("data", exist_ok=True)

folder_url = "https://drive.google.com/drive/folders/1NhBgnlArKS2kISV44Cl-JOexjGWTcllE"

# Download Google Drive folder INTO data/
gdown.download_folder(
    folder_url,
    output="data",
    quiet=False,
    use_cookies=False
)
# Out:
# Retrieving folder contents
# Processing file 18hvTODjbRukhryuXvBMoGlIacwRBiXqT 202409-citibike-tripdata_1.csv
# Processing file 1Y_TDcB-6h8CVNm2B0Z3ieZU6Z5Xr9xl7 202409-citibike-tripdata_2.csv
# Processing file 154Q2KqbGqO3sQUzoD7CyWhdDQFALQPIK 202409-citibike-tripdata_3.csv
# Processing file 12wKBAUO7q1LzdOathro1zuiZz5idj5B2 202409-citibike-tripdata_4.csv
# Processing file 1h6s9V-hvdRoe52vB1EUUza2psszEEkrB 202409-citibike-tripdata_5.csv
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=18hvTODjbRukhryuXvBMoGlIacwRBiXqT
# From (redirected): https://drive.google.com/uc?id=18hvTODjbRukhryuXvBMoGlIacwRBiXqT&confirm=t&uuid=78a19a7a-4bb7-4fde-9adf-a595c839f439
# To: /Users/erhan/Desktop/citibike/data/202409-citibike-tripdata_1.csv
# 100%|██████████| 195M/195M [00:23<00:00, 8.27MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1Y_TDcB-6h8CVNm2B0Z3ieZU6Z5Xr9xl7
# From (redirected): https://drive.google.com/uc?id=1Y_TDcB-6h8CVNm2B0Z3ieZU6Z5Xr9xl7&confirm=t&uuid=8e315602-e9f6-4b2a-ac9f-b5d40ad2a3d5
# To: /Users/erhan/Desktop/citibike/data/202409-citibike-tripdata_2.csv
# 100%|██████████| 195M/195M [00:25<00:00, 7.72MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=154Q2KqbGqO3sQUzoD7CyWhdDQFALQPIK
# From (redirected): https://drive.google.com/uc?id=154Q2KqbGqO3sQUzoD7CyWhdDQFALQPIK&confirm=t&uuid=c4e2317a-1d60-4adf-8a9a-4bca0d4898a9
# To: /Users/erhan/Desktop/citibike/data/202409-citibike-tripdata_3.csv
# 100%|██████████| 196M/196M [00:30<00:00, 6.35MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=12wKBAUO7q1LzdOathro1zuiZz5idj5B2
# From (redirected): https://drive.google.com/uc?id=12wKBAUO7q1LzdOathro1zuiZz5idj5B2&confirm=t&uuid=3553738c-6707-4e30-aceb-a5707ea5630d
# To: /Users/erhan/Desktop/citibike/data/202409-citibike-tripdata_4.csv
# 100%|██████████| 195M/195M [00:40<00:00, 4.83MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1h6s9V-hvdRoe52vB1EUUza2psszEEkrB
# From (redirected): https://drive.google.com/uc?id=1h6s9V-hvdRoe52vB1EUUza2psszEEkrB&confirm=t&uuid=c09594d7-2f64-4418-9628-b7561668225b
# To: /Users/erhan/Desktop/citibike/data/202409-citibike-tripdata_5.csv
# 100%|██████████| 196M/196M [00:31<00:00, 6.26MB/s]
# Download completed
# ['data/202409-citibike-tripdata_1.csv',
#  'data/202409-citibike-tripdata_2.csv',
#  'data/202409-citibike-tripdata_3.csv',
#  'data/202409-citibike-tripdata_4.csv',
#  'data/202409-citibike-tripdata_5.csv']

# %%
# Find the downloaded folder automatically
folder_name = 'data'

csv_files = [
    os.path.join(folder_name, f)
    for f in os.listdir(folder_name)
    if f.startswith("202409-citibike-tripdata") and f.endswith(".csv")
]

# Read and concatenate
df = pd.concat(
    [pd.read_csv(f) for f in csv_files],
    ignore_index=True
)

print(df.shape)
df.head()
# Out:
# /var/folders/xb/qx49vz8d0930c_62scc8m74w0000gn/T/ipykernel_34784/1025724460.py:12: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   [pd.read_csv(f) for f in csv_files],
# /var/folders/xb/qx49vz8d0930c_62scc8m74w0000gn/T/ipykernel_34784/1025724460.py:12: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   [pd.read_csv(f) for f in csv_files],
# /var/folders/xb/qx49vz8d0930c_62scc8m74w0000gn/T/ipykernel_34784/1025724460.py:12: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   [pd.read_csv(f) for f in csv_files],
# /var/folders/xb/qx49vz8d0930c_62scc8m74w0000gn/T/ipykernel_34784/1025724460.py:12: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   [pd.read_csv(f) for f in csv_files],
# /var/folders/xb/qx49vz8d0930c_62scc8m74w0000gn/T/ipykernel_34784/1025724460.py:12: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   [pd.read_csv(f) for f in csv_files],
# (4997898, 13)
#             ride_id  rideable_type               started_at  \
# 0  F58AB98A78A80FED   classic_bike  2024-09-06 17:38:01.429
# 1  6FC53627176E4527  electric_bike  2024-09-24 01:08:57.722
# 2  59F909611C4B9A41  electric_bike  2024-09-14 22:32:37.247
# 3  0825C91A785D1787  electric_bike  2024-09-08 17:35:46.831
# 4  5E6B3ED5913ACB28  electric_bike  2024-09-14 14:51:04.508
#
#                   ended_at      start_station_name start_station_id  \
# 0  2024-09-06 17:49:21.529  Columbus Ave & W 59 St          6986.07
# 1  2024-09-24 01:33:14.766  Columbus Ave & W 59 St          6986.07
# 2  2024-09-14 22:42:06.814    Division St & Bowery          5311.08
# 3  2024-09-08 17:45:38.688          E 2 St & Ave A           5553.1
# 4  2024-09-14 15:04:13.372        W 22 St & 10 Ave          6306.06
#
#                end_station_name end_station_id  start_lat  start_lng  \
# 0               W 29 St & 9 Ave        6416.06  40.769310 -73.984640
# 1  Meserole Ave & Manhattan Ave        5666.04  40.769310 -73.984640
# 2     Pearl St & Hanover Square        4993.02  40.714190 -73.996730
# 3               E 1 St & Bowery        5636.13  40.723077 -73.985836
# 4               E 1 St & Bowery        5636.13  40.746920 -74.004519
#
#      end_lat    end_lng member_casual
# 0  40.750073 -73.998393        member
# 1  40.727086 -73.952991        member
# 2  40.704718 -74.009260        member
# 3  40.724861 -73.992131        member
# 4  40.724861 -73.992131        member

# %%
os.makedirs("data", exist_ok=True)

# Save CSV into data folder
df.to_csv("data/202409_citibike_tripdata_combined.csv", index=False)
